# %%
from math import log
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib notebook

# %%
r2 = lambda x: round(x,2)

# %%
sns.set_style("whitegrid")

# %%
logOdds = np.array([log(i / (100 - i)) for i in random.choices(np.arange(1,100),k=10000)])

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.histplot(logOdds, bins=12)
ax2 = ax.twinx()
sns.kdeplot(logOdds, color="purple", ax=ax2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
odds = np.array([(i,(100 - i)) for i in random.choices(np.arange(1,100),k=10000)])

# %%
oddsWithCountRatio = np.array([*map(lambda x: r2(x[0] / x[1]),odds)])

# %%
odds[0][0]/odds[0][0]
# Out:
# 1.0

# %%
oddsWithProbRatio = (
    
    np.array([
                *map(
                    lambda x: r2((r2(x[0]/100))
                                 / r2(1 - (x[0]/100)))
                    ,odds
                )
    ])
)

# %%
sum(oddsWithProbRatio)
# Out:
# 40003.15999999958

# %%
sum(oddsWithCountRatio)
# Out:
# 40003.15999999958

# %%
sum(oddsWithProbRatio) == sum(oddsWithCountRatio)
# Out:
# True

# %%
odds[0][0] / odds[0][1]
# Out:
# 4.882352941176471

# %%
np.array([*map(lambda x: r2(x[0] / x[1]),odds)])
# Out:
# array([4.88, 0.04, 0.47, ..., 0.43, 0.47, 0.32])

# %%
1/99
# Out:
# 0.010101010101010102

# %%
49/51
# Out:
# 0.9607843137254902

# %%
88/12
# Out:
# 7.333333333333333

# %%
plt.figure()
sns.histplot(oddsWithCountRatio)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Count'>

# %%
3/2
# Out:
# 1.5

# %%
r2((3/5) / (1 - (3/5)))
# Out:
# 1.5

# %% [markdown]
# p / (1 - p) = odds

# %%
3/5
# Out:
# 0.6

# %%
class Account:
    
    def __init__(self,name,balance = 0):
        self.name = name
        self.balance = balance
        
    def deposit(self,deposit):
        if deposit > 0:
            self.balance += deposit
            print("New Balance: {}".format(self.balance))
        else:
            print("Can not deposit a negative value!")
        
    def withdraw(self,withdraw):
        if withdraw <= self.balance:
            self.balance -= withdraw
            print("New Balance: {}".format(self.balance))
        else:
            print("Can not withdraw more than current balance: {}".format(self.balance))

# %%
acct1 = Account("Kweayon Clark", 10000)

# %%
acct1.balance
# Out:
# 10000

# %%
acct1.withdraw(1000)
# Out:
# New Balance: 9000

# %%
acct1.withdraw(10000)
# Out:
# Can not withdraw more than current balance: 9000

# %%
acct1.deposit(3000)
# Out:
# New Balance: 12000

# %%
acct1.deposit(-3000)
# Out:
# Can not deposit a negative value!

# %%
acct1.withdraw(13000)
# Out:
# Can not withdraw more than current balance: 12000

# %%
6/1
# Out:
# 6.0

# %%
r2((6/7)/(1 -  (6/7)))
# Out:
# 6.0

# %%
r2 = lambda x: round(x,2)
